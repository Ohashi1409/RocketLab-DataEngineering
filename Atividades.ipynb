# %% [markdown]
# # Atividades a serem desenvolvidas ao longo do projeto
# ## Parte 1
# - [OK] Preparação e Upload dos dados
# - [OK] Notebook - Camada Bronze
#   - [OK] Criar banco de dados da camada bronze
#   - [OK] Criar tabelas na camada bronze
#   - [OK] Ingestão via API
# - [OK] Notebook - Camada Silver
#   - [OK] silver.dim_consumidores
#   - [OK] silver.fat_pedidos
#   - [OK] silver.fat_itens_pedidos
#   - [OK] silver.fat_pagamentos_pedidos
#   - [OK] silver.fat_avaliacoes_pedidos
#   - [OK] silver.dim_produtos
#   - [OK] silver.dim_vendedores
#   - [OK] silver.dim_categoria_produtos_traducao
#   - [OK] silver.dim_cotacao_dolar
#   - [OK] silver.fat_pedido_total
#   - [OK] Otimização Física (Delta Optimize)
#
# ## Parte 2
# ### Visão Comercial e Volume de Produtos
# - [OK] gold.fat_vendas_comercial
# - [OK] Rankings Comerciais - Exibição via display()
# ### Satisfação de Clientes e Qualidade de Parceiros
# - [OK] gold.fat_avaliacoes_clientes
# - [OK] Rankings de Qualidade - Exibição via display()
#
# ## Parte 3
# - [OK] Trigger (Agendamento) do pipeline para 13h todos os dias
# - [OK] 3 tasks sequenciais organizandos os notebooks na ordem correta (Bronze -> Silver -> Gold)
# - [OK] Aplicar dicas de ouro
#   - As atualizações de esquema devem ser toleradas usando .option("overwriteSchema", "true").
#     - Isso daqui é usado na camada gold pra quando for necessário adicionar ou remover colunas
#   - As gravações na camada Gold devem ser feitas no modo overwrite.
#
# ## Etapa final
# - [OK] Entregar os notebooks com os códigos em formato .ipynb.
# - [OK] Incluir comentários explicativos no código justificando as regras de negócio aplicadas.
# - [OK] Entregar o arquivo .yaml gerado pela exportação do Job no Databricks.
# - [OK] Entregar uma imagem (print) da execução de sucesso do Job exibindo as dependências.
# - [OK] Publicar os arquivos num repositório GitHub público.
